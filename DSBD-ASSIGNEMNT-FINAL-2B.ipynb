# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heartdisease.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Age',
#  'Sex',
#  'ChestPain',
#  'RestBP',
#  'Chol',
#  'Fbs',
#  'RestECG',
#  'MaxHR',
#  'ExAng',
#  'Oldpeak',
#  'Slope',
#  'Ca',
#  'Thal',
#  'AHD']

# %%
#------------------------------------------ 1.Data Cleaning ---------------------------------------------------

# %%
df.isnull()
# Out:
#      Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  \
# 0         False  False  False      False   False  False  False    False
# 1         False  False  False      False   False  False  False    False
# 2         False  False  False      False   False  False  False    False
# 3         False  False  False      False   False  False  False    False
# 4         False  False  False      False   False  False  False    False
# ..          ...    ...    ...        ...     ...    ...    ...      ...
# 298       False  False  False      False   False  False  False    False
# 299       False  False  False      False   False  False  False    False
# 300       False  False  False      False   False  False  False    False
# 301       False  False  False      False   False  False  False    False
# 302       False  False  False      False   False  False  False    False
#
#      MaxHR  ExAng  Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Unnamed: 0    0.0
# Age           0.0
# Sex           0.0
# ChestPain     0.0
# RestBP        0.0
# Chol          0.0
# Fbs           0.0
# RestECG       0.0
# MaxHR         0.0
# ExAng         0.0
# Oldpeak       0.0
# Slope         0.0
# Ca            0.0
# Thal          0.0
# AHD           0.0
# dtype: float64

# %%
#Use Series.fillna() function to fill out the missing values in the given series object. 
#Use a dictionary to pass the values to be filled corresponding to the different index labels in the series object.

# %%
df = df.fillna(0)
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df=df.fillna(df.mean())
df
# Out:
# C:\Users\legion\AppData\Local\Temp\ipykernel_34468\3834695363.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df=df.fillna(df.mean())
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# ...

# %%
#Optional
mean_value = df['Ca'].mean()
df['Ca'].fillna(value=mean_value , inplace=True)

# %%
df = df.fillna(method = 'ffill')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# AHD           0
# dtype: int64

# %%
# ------------------------------ ------------------- 2.Data Integration  ---------------------------------------------------

# %%
# selecting rows from 1 to 4 and columns from 2 to 4

# %%
subset1 = df.iloc[0:26,0:6]
subset1
# Out:
#     Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol
# 0            1   63    1       typical     145   233
# 1            2   67    1  asymptomatic     160   286
# 2            3   67    1  asymptomatic     120   229
# 3            4   37    1    nonanginal     130   250
# 4            5   41    0    nontypical     130   204
# 5            6   56    1    nontypical     120   236
# 6            7   62    0  asymptomatic     140   268
# 7            8   57    0  asymptomatic     120   354
# 8            9   63    1  asymptomatic     130   254
# 9           10   53    1  asymptomatic     140   203
# 10          11   57    1  asymptomatic     140   192
# 11          12   56    0    nontypical     140   294
# 12          13   56    1    nonanginal     130   256
# 13          14   44    1    nontypical     120   263
# 14          15   52    1    nonanginal     172   199
# 15          16   57    1    nonanginal     150   168
# 16          17   48    1    nontypical     110   229
# ...

# %%
subset2 = df.iloc[0:25,7:12]
subset2
# Out:
#     RestECG  MaxHR  ExAng  Oldpeak  Slope
# 0         2    150      0      2.3      3
# 1         2    108      1      1.5      2
# 2         2    129      1      2.6      2
# 3         0    187      0      3.5      3
# 4         2    172      0      1.4      1
# 5         0    178      0      0.8      1
# 6         2    160      0      3.6      3
# 7         0    163      1      0.6      1
# 8         2    147      0      1.4      2
# 9         2    155      1      3.1      3
# 10        0    148      0      0.4      2
# 11        2    153      0      1.3      2
# 12        2    142      1      0.6      2
# 13        0    173      0      0.0      1
# 14        0    162      0      0.5      1
# 15        0    174      0      1.6      1
# 16        0    168      0      1.0      3
# 17        0    160      0      1.2      1
# 18        0    139      0      0.2      1
# 19        0    171      0      0.6      1
# 20        2    144      1      1.8      2
# ...

# %%
subset3= df.iloc[26:51,0:6]
subset3
# Out:
#     Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol
# 26          27   58    0    nonanginal     120   340
# 27          28   66    0       typical     150   226
# 28          29   43    1  asymptomatic     150   247
# 29          30   40    1  asymptomatic     110   167
# 30          31   69    0       typical     140   239
# 31          32   60    1  asymptomatic     117   230
# 32          33   64    1    nonanginal     140   335
# 33          34   59    1  asymptomatic     135   234
# 34          35   44    1    nonanginal     130   233
# 35          36   42    1  asymptomatic     140   226
# 36          37   43    1  asymptomatic     120   177
# 37          38   57    1  asymptomatic     150   276
# 38          39   55    1  asymptomatic     132   353
# 39          40   61    1    nonanginal     150   243
# 40          41   65    0  asymptomatic     150   225
# 41          42   40    1       typical     140   199
# 42          43   71    0    nontypical     160   302
# ...

# %%
pd.concat([subset1,subset2])
# Out:
#     Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  RestECG  MaxHR  ExAng  \
# 0          1.0  63.0  1.0       typical   145.0  233.0      NaN    NaN    NaN
# 1          2.0  67.0  1.0  asymptomatic   160.0  286.0      NaN    NaN    NaN
# 2          3.0  67.0  1.0  asymptomatic   120.0  229.0      NaN    NaN    NaN
# 3          4.0  37.0  1.0    nonanginal   130.0  250.0      NaN    NaN    NaN
# 4          5.0  41.0  0.0    nontypical   130.0  204.0      NaN    NaN    NaN
# 5          6.0  56.0  1.0    nontypical   120.0  236.0      NaN    NaN    NaN
# 6          7.0  62.0  0.0  asymptomatic   140.0  268.0      NaN    NaN    NaN
# 7          8.0  57.0  0.0  asymptomatic   120.0  354.0      NaN    NaN    NaN
# 8          9.0  63.0  1.0  asymptomatic   130.0  254.0      NaN    NaN    NaN
# 9         10.0  53.0  1.0  asymptomatic   140.0  203.0      NaN    NaN    NaN
# 10        11.0  57.0  1.0  asymptomatic   140.0  192.0      NaN    NaN    NaN
# ...

# %%
pd.concat([subset1,subset3])
# Out:
#     Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol
# 0            1   63    1       typical     145   233
# 1            2   67    1  asymptomatic     160   286
# 2            3   67    1  asymptomatic     120   229
# 3            4   37    1    nonanginal     130   250
# 4            5   41    0    nontypical     130   204
# 5            6   56    1    nontypical     120   236
# 6            7   62    0  asymptomatic     140   268
# 7            8   57    0  asymptomatic     120   354
# 8            9   63    1  asymptomatic     130   254
# 9           10   53    1  asymptomatic     140   203
# 10          11   57    1  asymptomatic     140   192
# 11          12   56    0    nontypical     140   294
# 12          13   56    1    nonanginal     130   256
# 13          14   44    1    nontypical     120   263
# 14          15   52    1    nonanginal     172   199
# 15          16   57    1    nonanginal     150   168
# 16          17   48    1    nontypical     110   229
# ...

# %%
#--------------------------------------- 3.Data Transformation ---------------------------------------------------

# %%
df['ChestPain'].unique()
# Out:
# array(['typical', 'asymptomatic', 'nonanginal', 'nontypical'],
#       dtype=object)

# %%
df['ChestPain'] = df['ChestPain'].replace('typical',0)
df['ChestPain'] = df['ChestPain'].replace('asymptomatic',1)
df['ChestPain'] = df['ChestPain'].replace('nonanginal',2)
df['ChestPain'] = df['ChestPain'].replace('nontypical',3)
df
# Out:
#      Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1          0     145   233    1        2    150
# 1             2   67    1          1     160   286    0        2    108
# 2             3   67    1          1     120   229    0        2    129
# 3             4   37    1          2     130   250    0        0    187
# 4             5   41    0          3     130   204    0        2    172
# ..          ...  ...  ...        ...     ...   ...  ...      ...    ...
# 298         299   45    1          0     110   264    0        0    132
# 299         300   68    1          1     144   193    1        0    141
# 300         301   57    1          1     130   131    0        0    115
# 301         302   57    0          3     130   236    0        2    174
# 302         303   38    1          2     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# ...

# %%
df['Sex'] = df['Sex'].replace(1,'M')
df['Sex'] = df['Sex'].replace(0,'F')
df
# Out:
#      Unnamed: 0  Age Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0             1   63   M          0     145   233    1        2    150      0
# 1             2   67   M          1     160   286    0        2    108      1
# 2             3   67   M          1     120   229    0        2    129      1
# 3             4   37   M          2     130   250    0        0    187      0
# 4             5   41   F          3     130   204    0        2    172      0
# ..          ...  ...  ..        ...     ...   ...  ...      ...    ...    ...
# 298         299   45   M          0     110   264    0        0    132      0
# 299         300   68   M          1     144   193    1        0    141      0
# 300         301   57   M          1     130   131    0        0    115      1
# 301         302   57   F          3     130   236    0        2    174      0
# 302         303   38   M          2     138   175    0        0    173      0
#
# ...

# %%
for i in range(len(df['Chol'])):
  if i>200:
    df['Chol'] = df['Chol'].replace(i,'high')
  else:
    df['Chol'] = df['Chol'].replace(i,'low')
df
# Out:
#      Unnamed: 0  Age Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0             1   63   M          0     145  high    1        2    150      0
# 1             2   67   M          1     160  high    0        2    108      1
# 2             3   67   M          1     120  high    0        2    129      1
# 3             4   37   M          2     130  high    0        0    187      0
# 4             5   41   F          3     130  high    0        2    172      0
# ..          ...  ...  ..        ...     ...   ...  ...      ...    ...    ...
# 298         299   45   M          0     110  high    0        0    132      0
# 299         300   68   M          1     144   low    1        0    141      0
# 300         301   57   M          1     130   low    0        0    115      1
# 301         302   57   F          3     130  high    0        2    174      0
# 302         303   38   M          2     138   low    0        0    173      0
#
# ...

# %%
#------------------------------------------- 5. Model Building ---------------------------------------------------

# %%
feature_cols = ['Age','ChestPain','RestBP','Fbs','RestECG','MaxHR','Slope']
X = df[feature_cols]
y = df.AHD

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 2, random_state = 0)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

from sklearn import metrics
print("Accuracy: ", metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.7362637362637363

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.71      0.86      0.78        49
#          Yes       0.78      0.60      0.68        42
#
#     accuracy                           0.74        91
#    macro avg       0.75      0.73      0.73        91
# weighted avg       0.74      0.74      0.73        91

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = df[['Ca','Slope']]
y= df['Age']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error: ", mse)
print("R2 Score: ", r2)
# Out:
# Mean Squared Error:  62.9224440520982
# R2 Score:  0.20282000643265263

# %%
X_test
# Out:
#      Age  ChestPain  RestBP  Fbs  RestECG  MaxHR  Slope
# 204   43          1     110    0        0    161      1
# 159   68          2     118    0        0    151      1
# 219   59          1     138    0        2    182      1
# 174   64          1     145    0        2    132      2
# 184   60          1     158    0        2    161      1
# ..   ...        ...     ...  ...      ...    ...    ...
# 106   59          1     140    0        0    162      1
# 105   54          3     108    0        0    156      1
# 67    54          2     150    0        2    165      1
# 291   55          3     132    0        0    166      1
# 247   47          1     110    0        2    118      2
#
# [91 rows x 7 columns]

# %%
from sklearn import tree
tree.plot_tree(clf);

# %%
#----------------------------------------- 4. Error Correction ------------------------------------------------

# %%
df.columns = ['Unnamed: 0','Age','Sex','ChestPain','RestBP','Chol','Fbs','RestECG','MaxHR','ExAng','Oldpeak','Slope','Ca','Thal','AHD']
df
# Out:
#      Unnamed: 0  Age Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0             1   63   M          0     145  high    1        2    150      0
# 1             2   67   M          1     160  high    0        2    108      1
# 2             3   67   M          1     120  high    0        2    129      1
# 3             4   37   M          2     130  high    0        0    187      0
# 4             5   41   F          3     130  high    0        2    172      0
# ..          ...  ...  ..        ...     ...   ...  ...      ...    ...    ...
# 298         299   45   M          0     110  high    0        0    132      0
# 299         300   68   M          1     144   low    1        0    141      0
# 300         301   57   M          1     130   low    0        0    115      1
# 301         302   57   F          3     130  high    0        2    174      0
# 302         303   38   M          2     138   low    0        0    173      0
#
# ...

# %%
df['Ca'].unique()
# Out:
# array([0., 3., 2., 1.])

# %%
(df['Ca']=='?').sum()
# Out:
# 0

# %%
import numpy as np
df.loc[df['Ca']=="?", 'Ca']=np.NaN
df['Ca'].unique()
# Out:
# array([0., 3., 2., 1.])

# %%
df['Thal'].unique()
# Out:
# array(['fixed', 'normal', 'reversable', 0], dtype=object)

# %%
df.loc[df['Thal']=='?','Thal']=np.NaN
df['Thal'].unique()
# Out:
# array(['fixed', 'normal', 'reversable', 0], dtype=object)
